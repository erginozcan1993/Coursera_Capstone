# %% [markdown]
# # Ergin Ozcan's Capstone Project: Cafes in Istanbul

# %% [markdown]
# ## This project aims to complete IBM Data Science Specialization from Coursera. It will contains several codes about this project.

# %% [markdown]
# This project provides find total of cafe business in District of Istanbul, the datasets used to finding report and objectives of complete the project.

# %% [markdown]
# ## 1. Problem

# %% [markdown]
# Coffee sector in Turkey is competitive area. Every people wants to open new cafe. Although, as same as other business, every cafe will fall and close without market research. Every district in Istanbul got difficult situation. So, a cafe concept which was suitable in one district are unsuitable in other district.

# %% [markdown]
# ## 2. Data Sets

# %% [markdown]
# I use Foursquare API because they are popular at the city guide and listed every related business in the area. Although, they do not covering all-over Istanbul in one place. So, if we search Istanbul's situation, we look area to area.

# %% [markdown]
# ## 3. Code Set

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# ...

# %% [markdown]
# ### After setting important code. I launch Foursquare account and ID for starting project

# %% [markdown]
# ### I hide this code for the security reasons.

# %% [markdown]
# CLIENT_ID = 'My Foursquare ID'
# CLIENT_SECRET = 'My Foursquare Secret'
# VERSION = '20180604'
# LIMIT = 30
# print('Your credentails:')
# print('CLIENT_ID: ' + CLIENT_ID)
# print('CLIENT_SECRET:' + CLIENT_SECRET)

# %% [markdown]
# ### We start to select "Istanbul".

# %%
address = 'Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 41.0766019 29.052495

# %%
search_query = 'Café'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Café .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RVIZX1Y3AE3UTDQ25BLX45L2RSMCI4SIGE1FRVNFN4DKZALE&client_secret=ZNZXLORN4P5ALVLF5ECD0ZOTHMFL3LDMYZIIDCHUEFVJMHF1&ll=41.0766019,29.052495&v=20180604&query=Café&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e48150771c428001b12fdd7'},
#  'response': {'venues': [{'id': '4e4aacde18a83cda37df4408',
#     'name': 'Ihlamur Cafe',
#     'location': {'address': 'Kandilli İskelesi No:2/A',
#      'lat': 41.074346008992286,
#      'lng': 29.05848982714884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.074346008992286,
#        'lng': 29.05848982714884}],
#      'distance': 562,
#      'cc': 'TR',
#      'city': 'İstanbul',
#      'state': 'İstanbul',
#      'country': 'Türkiye',
#      'formattedAddress': ['Kandilli İskelesi No:2/A', 'İstanbul', 'Türkiye']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1581782439',
#     'hasPerk': False},
#    {'id': '4ed8b5c4e5fa78b16c090a52',
# ...

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
#
#                          id          location.address location.cc  \
# 0  4e4aacde18a83cda37df4408  Kandilli İskelesi No:2/A          TR
# 1  4ed8b5c4e5fa78b16c090a52                  Akmerkez          TR
# 2  56267516498ec64159c66348    Bebek Caddesi İstanbul          TR
# 3  57a76e65498e7e1094af63b4                       NaN          TR
# 4  55bdef58498e69dea7c7dffb                       NaN          TR
#
#   location.city location.country location.crossStreet  location.distance  \
# 0      İstanbul          Türkiye                  NaN                562
# ...

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                         name      categories                   address  cc  \
# 0               Ihlamur Cafe            Café  Kandilli İskelesi No:2/A  TR
# 1                     S Cafe            Café                  Akmerkez  TR
# 2  İstanbul Bebek Drank Cafe     Coffee Shop    Bebek Caddesi İstanbul  TR
# 3      Kandilli Ihlamur Cafe       Cafeteria                       NaN  TR
# 4                Taşkın Cafe  Breakfast Spot                       NaN  TR
#
#        city  country     crossStreet  distance  \
# 0  İstanbul  Türkiye             NaN       562
# 1       NaN  Türkiye             NaN        80
# 2  İstanbul  Türkiye  Etiler Caddesi       410
# 3       NaN  Türkiye             NaN       557
# 4       NaN  Türkiye             NaN       531
#
#                                     formattedAddress  \
# 0      [Kandilli İskelesi No:2/A, İstanbul, Türkiye]
# 1                                [Akmerkez, Türkiye]
# 2  [Bebek Caddesi İstanbul (Etiler Caddesi), İsta...
# ...

# %% [markdown]
# ### In this code, we saw only five results and only three results are dedicated to cafe. Although, I saw at least 500 results in my search at Google, TripAdvisor, Foursquare etc.

# %%
dataframe_filtered.name
# Out:
# 0                 Ihlamur Cafe
# 1                       S Cafe
# 2    İstanbul Bebek Drank Cafe
# 3        Kandilli Ihlamur Cafe
# 4                  Taşkın Cafe
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Now, we look into Yenikoy. Yenikoy's coordinates are 41.12 and 29.07

# %%
latitude = 41.120425
longitude = 29.069133

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=RVIZX1Y3AE3UTDQ25BLX45L2RSMCI4SIGE1FRVNFN4DKZALE&client_secret=ZNZXLORN4P5ALVLF5ECD0ZOTHMFL3LDMYZIIDCHUEFVJMHF1&ll=41.120425,29.069133&v=20180604&radius=500&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Köybaşı Caddesi.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Köybaşı Caddesi.'

# %%
items = results['response']['groups'][0]['items']
items[0]

dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(30)
# Out:
#                                         name                       categories  \
# 0                     Sait Halim Paşa Yalısı                    Historic Site
# 1                                      Qumru                 Kumru Restaurant
# 2                            Yeniköy Kahvesi                             Café
# 3                                 Yeni Damla                      Pastry Shop
# 4                          Yeniköy Lokantası  Turkish Home Cooking Restaurant
# 5                            Hopdaddy Burger                     Burger Joint
# 6                              Yenikoy Sütiş                   Breakfast Spot
# 7                               Azur Yeniköy               Seafood Restaurant
# 8                          İskele Restaurant               Seafood Restaurant
# 9                          Yeniköy Kitapçısı                        Bookstore
# 10                                 Timothy's                           Bistro
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Yeniköy',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### In Yenikoy, only nine results out of 30 results are related in "Café" terms. Tasse Coffee Co., Kahve Dunyasi and Coffee Nero are excluded and coiffeur are listed in Foursquare. Now, we look Heybeliada and Buyukada. Which these islands are two islands of the Prince Islands.

# %%
address = 'Heybeliada, Buyukada'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

earch_query = 'Café'
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head(10)

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 40.87875135 29.100363137105923
# Café .... OK!
#                             name            categories  \
# 0                    Gencay Cafe                  Café
# 1                      Cafe Keyf                  Café
# 2                  Adaturka Cafe                  Café
# 3                     Bahar Cafe                  Café
# 4                       Luz Café                  Café
# 5              Rest El Faro Cafe                  Café
# 6                   Özdemir Cafe                  Café
# 7            CanCan İddaa & Cafe           Snack Place
# 8                    Cafe Zıyade                  Café
# 9                   Koridor Cafe                  Café
# 10                     Lady Cafe                  Café
# 11                 Denizatı Cafe                  Café
# 12              Heybeli Ada Cafe  Fast Food Restaurant
# 13               Heybeliada Cafe                  Café
# 14                 Nazlıgül Cafe                Bakery
# ...

# %%
dataframe_filtered.name
# Out:
# 0                      Gencay Cafe
# 1                        Cafe Keyf
# 2                    Adaturka Cafe
# 3                       Bahar Cafe
# 4                         Luz Café
# 5                Rest El Faro Cafe
# 6                     Özdemir Cafe
# 7              CanCan İddaa & Cafe
# 8                      Cafe Zıyade
# 9                     Koridor Cafe
# 10                       Lady Cafe
# 11                   Denizatı Cafe
# 12                Heybeli Ada Cafe
# 13                 Heybeliada Cafe
# 14                   Nazlıgül Cafe
# 15                      Cafe Me-Ze
# 16                     Cafe Gencay
# 17                  Kardesler cafe
# 18                      Torpi Cafe
# 19                     Ceylan Cafe
# 20                       Ezop Cafe
# 21    Mimosa Cafe & Van Kahvaltısı
# 22                      Cafe Ilker
# 23                      Deniz Cafe
# 24                    koridor cafe
# 25               Ada Internet Cafe
# 26    Neval Cafe Restaurant Bistro
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Luz Café',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In Heybeliada, all cafes are located at "Rıhtım Avenue". Because this avenue have contains Pier and "Heybeliada" is more available in this business than Buyukada.

# %%
address = 'Büyükada, Adalar'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 40.856354499999995 29.119036629831754
#                          name categories           address  cc       city  \
# 0  Lunapark Cafe & Restaurant       Café  Birlik Meydanı 1  TR     Adalar
# 1        Taksim ale beer cafe       Café               NaN  TR        NaN
# 2                Papagan Cafe       Café               NaN  TR  Büyük Ada
#
#    country      crossStreet  distance  \
# 0  Türkiye  Çankaya Caddesi       172
# 1  Türkiye              NaN       453
# 2  Türkiye              NaN       519
#
#                                     formattedAddress  \
# 0  [Birlik Meydanı 1 (Çankaya Caddesi), Büyükada,...
# 1                                          [Türkiye]
# 2                               [Büyük Ada, Türkiye]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.85744601682797...  40.857446  29.120485
# 1  [{'label': 'display', 'lat': 40.85418433677049...  40.854184  29.123591
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Papagan Cafe',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In Buyukada, only three cafes are available. Because rent price is expensive than Heybeliada. Although, Buyukada is most popular place in the Prince Islands.

# %%
address = 'Tuzla, Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 40.8166668 29.3008332
#                              name                       categories  \
# 0                Oğuz Cafe - Büfe                         Tea Room
# 1                     Cafe Dündar                             Café
# 2                   Kendince Cafe                      Coffee Shop
# 3      Kırmızı Playstation & Cafe                           Arcade
# 4                Black's Cafe Bar                              Pub
# 5                      Sahil Cafe                             Café
# 6         Ren Chocolate Cafe Shop                             Café
# 7    Mulier Butik & Aksesuar Cafe                         Boutique
# 8             Beyaz İnternet Cafe                           Arcade
# 9                            Cafe                             Café
# 10   Little Pilot Cafe & Bistro ️                             Café
# 11                      Ogün Cafe                             Café
# 12         Sherlock Bistro & Cafe                           Bistro
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel


folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Oguz Cafe - Bufe',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)


venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In Tuzla, usually cafés are located in Ahmet Kilic Boulevard. Although, Tuzla also have Viaport Marina and they have several coffe shop in the Marina. Students from ITU are main audience of these cafés.

# %%
address = 'Sile, Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.1744067 29.6125216
#                           name            categories  \
# 0      Bilir Cafe & Patisserie                  Café
# 1                   Çakıl Cafe                  Café
# 2                   Cafe Rouge             Gastropub
# 3                    Cafe miss                  Café
# 4        Deniz Cafe&restaurant     Fish & Chips Shop
# 5          Sago Ice Cream Cafe                  Café
# 6    The Game Playstation Cafe                Arcade
# 7          İbişoğlu iddaa cafe  Arts & Entertainment
# 8           Cafe Beyzade Pizza           Pizza Place
# 9           Elit İnternet Cafe         Internet Cafe
# 10                Oksijen Cafe                  Café
# 11         İbişoğlu iddaa cafe    Athletics & Sports
# 12             ASYA Börek&Cafe            Food Court
# 13       Olimpia Halisaha&Cafe          Soccer Field
# 14  Fusa Restaurant & Cafe Bar            Restaurant
# 15           Eklerr Pasta&Cafe                  Café
# ...

# %% [markdown]
# In Sile, cafés are widely available. Although, some internet cafés are included in this list but mainly this area got competitive in the this sector.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Çakıl Cafe',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Besiktas Trio (Akaretler/Barbaros Boulevard, Bebek and Ortakoy)

# %% [markdown]
# Besiktas district have several popular places which known very popular in Istanbul. From Besiktas Square to Bebek, from Levent to Arnavutkoy, from Ortakoy to Kurucesme, they got mainly crowded all day.
#
# In Besiktas, Barbaros Boulevard and Akaretler are very popular places because their transport is very easy from other districts. Bebek is popular place for many entertainment. Although, this area's cafe (except Starbucks and Coffee Nero) are served high prices. In Ortakoy, they want to reach these popularity. Although, they can't reach too much people.

# %%
address = 'Besiktas'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.0428465 29.0075283
#                         name      categories  \
# 0           Çıtır Cafe & Pub             Pub
# 1            Sahil Rest Cafe            Café
# 2             The House Café            Café
# 3         Beltaş Rest - Cafe            Café
# 4       Hakan Cafe & Pastane            Café
# 5                  Genç Cafe        Tea Room
# 6         Palmiye Sokak Cafe            Café
# 7     Minoa Bookstore & Café       Bookstore
# 8               Cafe De Cuba            Café
# 9     Carmenta Kahvaltı Cafe  Breakfast Spot
# 10   Barbaros Cafe & Nargile            Café
# 11                Limos Cafe  Breakfast Spot
# 12    Balkon Cafe & Kahvaltı  Breakfast Spot
# 13             Cafe Platonik            Café
# 14         Virgil Cafe & Bar             Bar
# 15          Chops Cafe & Pub             Bar
# 16        Durak Nargile Cafe            Café
# 17       Uğur Cafe & Nargile            Café
# 18       Külüstür Cafe & Pub             Bar
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Çakıl Cafe',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Bebek, Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.0790159 29.0439589
#                                      name      categories  \
# 0                Balkon Cafe & Restaurant            Café
# 1                               Starbucks     Coffee Shop
# 2                  Füme Café & Restaurant      Restaurant
# 3                              Bebek Cafe            Café
# 4                                 Kırıntı      Restaurant
# 5                         Healthyish Cafe            Café
# 6                         Cafe Nero Bebek            Café
# 7                               Past Cafe            Café
# 8                         Zenith Cafe Bar     Music Venue
# 9          Rumeli Kale Cafe&Pastane,Bebek  Breakfast Spot
# 10                        cafe de marango      Steakhouse
# 11                             Baçik Cafe            Café
# 12                      Nargile Boom Cafe      Hookah Bar
# 13                            Garden Cafe            Café
# 14                          Baguetta Cafe            Café
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Çakıl Cafe',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Ortakoy, Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.0546272 29.0281901
#                                   name                  categories  \
# 0                       Cafe Bosphorus                        Café
# 1                       TRT WORLD CAFE         Corporate Cafeteria
# 2                        Cafe De Paris           French Restaurant
# 3                  Pasha İnternet Cafe                      Arcade
# 4                        Cafe Karanfil                        Café
# 5                          Cafe Nayino                  Restaurant
# 6                            Maya cafe             Other Nightlife
# 7                           Meyve Cafe                        Café
# 8                   cafe mirayla house                        Café
# 9                    Şiir Cafe Nargile                  Hookah Bar
# 10                     Allı Börek&Cafe          Turkish Restaurant
# 11                     Bousphours Cafe                      Castle
# 12               Gezegen Internet Cafe                      Arcade
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Cafe Bosphorus',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Moda, Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 40.9811687 29.0254706
#                                 name    categories  \
# 0                           Kev Cafe          Café
# 1                Page Cafe & Gallery   Coffee Shop
# 2                700GR Bakery & Cafe          Café
# 3                          Cafe MOON          Café
# 4         BaDe Chocolatier Cafe Moda          Café
# 5   Cafe Baba Vanga Fal Cafe Kadıköy   Coffee Shop
# 6                           CAFE 37A    Restaurant
# 7                    Dodo Cafe & Pub          Café
# 8                         Lokum Cafe          Café
# 9                        Beltur Cafe          Café
# 10                   Cafe Des Femmes          Café
# 11       Angeli Carnevale Butik Cafe      Boutique
# 12              Mystic Art Cafe-Moda          Café
# 13                          Gaf Cafe          Café
# 14                     İxir Cafe Bar           Bar
# 15                     İki Kedi Cafe          Café
# 16                        Böcek Cafe          Café
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Cafe Bosphorus',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Nisantasi, Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.0516865 28.9916962
#                             name                categories  \
# 0                 The House Café                      Café
# 1          The House Cafe Corner                      Café
# 2       Symbol Cafe & Restaurant                      Café
# 3    Grandma Artisan Bakery Cafe                      Café
# 4                    Rumeli Cafe                      Café
# 5                      Cafe Zone                      Café
# 6                     Polen Cafe                      Café
# 7             Prestij Cafe & Bar                       Bar
# 8                      Cafe Wien       Austrian Restaurant
# 9          Mono Cafe & Brasserie                      Café
# 10       Lokumm Cafe & Brasserie                     Diner
# 11                    Bambi Cafe      Fast Food Restaurant
# 12          DERİ SHOW CAFE NTASİ               Snack Place
# 13          Creperie Cafe Bistro         French Restaurant
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='The House Cafe Corner',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### In Nisantasi, they got great names about coffee. Outside of great coffee companies, MOC is most popular in the third-wave coffee and they use different menus. Other cafés wants to popular as same as MOC and Starbucks Reserve.

# %% [markdown]
# ## Beylikduzu Area (Center of Beylikduzu and Gurpinar Beach)

# %% [markdown]
# Beylikduzu is developing district at social activities in Istanbul. Several cafes are launched last year in Beylikduzu and they attracts people in nowadays. Maybe they are less popular than Sisli, Besiktas and Kadikoy. Although, they have a potential. Gurpinar is the beach of Beylikduzu and they got many cafes. Although, Gurpinar is less developed than Beylikduzu by the transport difficulty.

# %%
address = 'Beylikdüzü, Istanbul'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.0010788 28.642054
#                                    name           categories  \
# 0         Kuğulu Park Cafe & Restaurant                 Café
# 1              Lochka Cafe & Restaurant                 Café
# 2                  Şato Cafe Restaurant                 Café
# 3              Blue Cafe&Bar Restaurant   Turkish Restaurant
# 4                          Menekşe Cafe                 Café
# 5                        Cafe De Zigana                 Café
# 6                       Alem teras cafe                 Café
# 7                    İnternational Cafe        Historic Site
# 8                         BY CAFE SANAT                 Café
# 9       By Sanat | Kitap | Sanat | Cafe                 Café
# 10       Ihlamur Cafe & Beylikdüzü Aksm           Food Court
# 11                           Cafe Yeşil                 Café
# 12                          Big Mamma’s           Restaurant
# 13                           Şölen Cafe                 Café
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='The House Cafe Corner',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Gürpınar, Beylikdüzü'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 40.9864388 28.6030771
#                                                  name             categories  \
# 0                              Para Cafe & Restaurant                   Café
# 1                   BWSC Cafe Powered by DPI Sportive              Cafeteria
# 2                               Alisayit pastane-cafe         Breakfast Spot
# 3                               Teras Cafe&Restaurant                   Café
# 4                                         Kafega Cafe               Tea Room
# 5                                          Cafe Kerem                   Café
# 6                                 Tercih Pastane&Cafe                   Café
# 7                                  Mebuta  Sakin Cafe             Whisky Bar
# 8                         Fatih % Fetih İnternet Cafe                 Arcade
# 9                                         Lubara Cafe            Coffee Shop
# 10                                         zollu cafe        Other Nightlife
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='The House Cafe Corner',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Bagcilar'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.0338992 28.8578982
#                              name            categories  \
# 0   Pandora Cafe & Restaurant      Café
# 1   myROC Cafe&Restaurant          Café
# 2   Cafe Sakoya                    Hookah Bar
# 3   OTTOMAN PS3 CAFE               Gaming Cafe
# 4   Cafe Keyf  Playstation         Video Game Store
# 5   Bambu Cafè                     Café
# 6   Şans Cafe                      Café
# 7   Angels Playstation Cafe        Arcade
# 8   Metinler İnternet Cafe         Arcade
# 9   Mydonose Cafe                  Arcade
# 10  Mira Cafe                      Café
# 11  Hizmet İnternet Cafe           Arcade
# 12  Kral Cafe •21•                 Nightclub
# 13  Çatı Câfe                      Hookah Bar
# 14  Dilek Pasta Cafe & Restaurant  Café
# 15  Osmanlı Nargile Cafe           Hookah Bar
# 16  Efe İnternet Cafe              Internet Cafe
# 17  çıt çıt cafe                   Café
# 18  Çatı Cafe                      Café
# 19  CAFE BALABAN                   Arts & Entertainment
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='The House Cafe Corner',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### In Bagcilar, coffee is usually served by patisserie. Although, many internet cafe is listed by Foursquare.

# %%
address = 'Gungoren'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results

venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# 41.0228713 28.8726289
#                                   name            categories  \
# 0              DeJaVu PlayStation Cafe                Arcade
# 1               MEKAN Cafe PLAYSTATİON                Arcade
# 2             Üzüm Şeftali Cafe&Bistro            Hookah Bar
# 3                    Çamlıca Park Cafe                  Café
# 4                         Cafe dé PoKa            Hookah Bar
# 5               Özgül Cafe & Restorant                Bistro
# 6   Cevher Dudayev Parkı Şehrigül Cafe                  Park
# 7                                 Cafe    Belgian Restaurant
# 8                     Hazal Pasta&Cafe                  Café
# 9                      Caffe Del Borgo                  Café
# 10                        Osmanlı Cafe              Tea Room
# 11                         3d ps3 cafe           Gaming Cafe
# 12                    Curcuna Cafe&Bar                   Bar
# 13                     Siyah İnci Cafe                  Café
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='The House Cafe Corner',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### In Gungoren, situation is similar than Bagcilar. Coffee is usually served by patisserie & cafe.

# %% [markdown]
# ## Results

# %% [markdown]
# In modern terms of Café is served at the center districts of Istanbul as well as Yenikoy, Balat and Kuzguncuk. In conservative areas, usually sells Nescafe in Patisserie and third-wave coffee station term may be opposed by these districts. Although, we have a Balat and Kuzguncuk example. If we wait a time, may be Bagcilar does active in third-wave coffee station.
